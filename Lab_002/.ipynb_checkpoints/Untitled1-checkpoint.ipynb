# %%
# import packages for analysis and modeling
import pandas as pd  # data frame operations
#from pandas.tools.plotting import scatter_matrix  # scatter plot matrix
import statsmodels.api as sm  # statistical models (including regression)
import statsmodels.formula.api as smf  # R-like model specification
import numpy as np  # arrays and math functions
import matplotlib.pyplot as plt  # 2D plotting
#import zipcodes
#import pyzipcode
import time

from pandas import Series
from scipy.stats import uniform  # for training-and-test split
from scipy.stats import boxcox
from sklearn.tree import DecisionTreeRegressor  # machine learning tree
from sklearn.ensemble import RandomForestRegressor # ensemble method
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from pprint import pprint
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from math import sqrt





# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff



# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# %%
house = pd.read_csv('clean_house_data.csv', encoding = "ISO-8859-1")

states = house.State.unique()
states = states[28:29] #only AR

df = pd.DataFrame(columns=['State', 'Zip', 'Date', 'Prediction'])

start_time = time.time()
for s in states:
    ar = house.loc[house.State == s]
    ar = ar.drop(ar.loc[:,ar.columns[6:15]], axis=1)
    ar = ar.drop(ar.loc[:,ar.columns[258:]], axis=1)
    
    ar_validate = house.loc[house.State == s]
    ar_validate = ar_validate.drop(ar_validate.loc[:,ar_validate.columns[6:267]], axis=1)
    
    zips = ar.RegionName.unique()
    #zips = zips[:1] # for testing
    
    training = pd.melt(ar, id_vars=['RegionName'], value_vars=ar.columns[6:])
    testing = pd.melt(ar_validate, id_vars=['RegionName'], value_vars=ar_validate.columns[6:])
    
    #print(ar.columns)
    
    for z in zips:
        train_region = training.loc[training.RegionName == z]
        test_region = testing.loc[testing.RegionName == z]
        
        X = train_region.value.astype('float32').values
        Y = test_region.value.astype('float32').values
        D = test_region.variable.values
        
        train, test, date = X, Y, D
        # walk-forward validation
        history = [x for x in train]
        predictions = list()
        
        print('Prediction for State: {}, Zip: {}'.format(s, str(z)))
        
        for i in range(len(test)):
            # difference data
            months = 12
            diff = difference(history, months)
            # predict
            model = ARIMA(diff, order=(2,1,0))
            model_fit = model.fit(trend='nc', disp=0)
            yhat = model_fit.forecast()[0]
            #print(yhat)
            yhat = inverse_difference(history, yhat, months)
            predictions.append(yhat)
            # observation
            obs = test[i]
            history.append(obs)
            #print('Prediction for Date: {} : ${}'.format(date[i], round(float(yhat),2)))
            #print('>Predicted=%.3f, Expected=%3.f' % (yhat, date[i]))
            df = df.append({'State': 'AR',
                            'Zip': z,
                            'Date':date[i],
                            'Prediction':round(float(yhat),0)
                           }, ignore_index=True)
            
        # report performance
        mse = mean_squared_error(test, predictions)
        rmse = sqrt(mse)
        print('RMSE: %.3f' % rmse)
        
        df.to_csv('ar_zip_analysis.csv', index = False)
        
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72401
# RMSE: 752.478
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 71913
# RMSE: 899.323
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72034
# RMSE: 462.538
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72701
# RMSE: 885.443
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72076
# RMSE: 1139.441
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72756
# RMSE: 501.178
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72758
# RMSE: 725.813
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72703
# RMSE: 868.469
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72450
# RMSE: 771.900
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 71854
# RMSE: 1403.778
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72712
# RMSE: 760.859
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72120
# RMSE: 444.412
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72023
# RMSE: 1442.746
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72762
# RMSE: 452.585
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72143
# RMSE: 611.513
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72204
# RMSE: 693.742
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72653
# RMSE: 736.090
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72032
# RMSE: 656.890
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72956
# RMSE: 453.556
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 71901
# RMSE: 492.570
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72601
# RMSE: 1023.465
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72704
# RMSE: 383.201
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72205
# RMSE: 631.457
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72113
# RMSE: 553.902
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72404
# RMSE: 566.947
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72903
# RMSE: 892.579
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72211
# RMSE: 499.896
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72223
# RMSE: 944.862
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72015
# RMSE: 442.004
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72501
# RMSE: 420.848
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72116
# RMSE: 776.905
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72118
# RMSE: 464.490
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72301
# RMSE: 1196.995
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 71909
# RMSE: 670.860
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72901
# RMSE: 1463.551
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72761
# RMSE: 719.047
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72802
# RMSE: 575.871
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72904
# RMSE: 978.493
# Index(['RegionName', 'variable', 'value'], dtype='object')
# Prediction for State: AR, Zip: 72715
